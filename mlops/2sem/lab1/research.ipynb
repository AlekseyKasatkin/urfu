# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
1
# Out:
# 1

# %%
train_data = pd.read_csv('training_data/training_data.csv')
test_data = pd.read_csv('testing_data/test_data.csv')

# %%
scaler = StandardScaler()
train_data_scaled = scaler.fit_transform(train_data[['temperature']])
train_data_scaled_df = pd.DataFrame(train_data_scaled, columns=['temperature'])
train_data_scaled_df['day'] = train_data['day']
train_data_scaled_df
# Out:
#     temperature  day
# 0     -0.103826  179
# 1     -1.017864  115
# 2      1.367714   96
# 3     -1.140296   24
# 4      1.468885    9
# ..          ...  ...
# 75    -1.145296  111
# 76    -0.902571  109
# 77    -0.413096  197
# 78    -1.213266  141
# 79     1.566883  216
#
# [80 rows x 2 columns]

# %%
test_data_scaled = scaler.transform(test_data[['temperature']])
test_data_scaled_df = pd.DataFrame(test_data_scaled, columns=['temperature'])
test_data_scaled_df['day'] = test_data['day']
test_data_scaled_df
# Out:
#     temperature  day
# 0     17.655698  179
# 1     11.454154  115
# 2     29.951799   96
# 3     10.548865   24
# 4     29.900675    9
# ..          ...  ...
# 75    10.960648  111
# 76    12.875913  109
# 77    16.475378  197
# 78    10.519168  141
# 79    30.265582  216
#
# [80 rows x 2 columns]

# %% [markdown]
# # Model

# %%
from sklearn.linear_model import LinearRegression
import joblib

# %%
train_data = pd.read_csv('training_data/temperature_train_scaled.csv')
train_data
# Out:
#     temperature  day
# 0     -0.225971  179
# 1     -1.137441  115
# 2      1.241435   96
# 3     -1.259528   24
# 4      1.342321    9
# ..          ...  ...
# 75    -1.264514  111
# 76    -1.022471  109
# 77    -0.534372  197
# 78    -1.332294  141
# 79     1.440044  216
#
# [80 rows x 2 columns]

# %%
X_train = train_data['day'].values.reshape(-1, 1)
y_train = train_data['temperature']

# %%
X_train
# Out:
# array([[179],
#        [115],
#        [ 96],
#        [ 24],
#        [  9],
#        [139],
#        [255],
#        [ 45],
#        [185],
#        [125],
#        [257],
#        [173],
#        [117],
#        [ 73],
#        [211],
#        [229],
#        [175],
#        [196],
#        [118],
#        [113],
#        [ 60],
#        [  6],
#        [ 30],
#        [208],
#        [233],
#        [ 84],
#        [ 66],
#        [144],
#        [ 97],
#        [159],
#        [ 19],
#        [ 67],
#        [114],
#        [104],
#        [150],
#        [ 82],
#        [213],
#        [ 15],
#        [ 46],
#        [236],
#        [242],
#        [ 33],
#        [154],
#        [ 77],
#        [244],
#        [ 16],
#        [ 10],
#        [152],
#        [ 79],
#        [101],
#        [263],
#        [ 25],
#        [ 78],
#        [172],
#        [232],
#        [ 18],
#        [ 90],
#        [182],
#        [ 75],
#        [155],
#        [119],
#        [183],
#        [254],
#        [164],
#        [ 68],
#        [239],
#        [ 55],
#        [ 86],
#        [261],
#        [ 38],
#        [146],
#        [178],
#        [237],
#        [195],
#        [124],
#        [111],
#        [109],
#        [197],
#        [141],
#        [216]])

# %%
y_train
# Out:
# 0    -0.225971
# 1    -1.137441
# 2     1.241435
# 3    -1.259528
# 4     1.342321
#         ...
# 75   -1.264514
# 76   -1.022471
# 77   -0.534372
# 78   -1.332294
# 79    1.440044
# Name: temperature, Length: 80, dtype: float64

# %%
model = LinearRegression()
model.fit(X_train, y_train)
model
# Out:
# LinearRegression()

# %%
joblib.dump(model, 'model/model.pkl')
# Out:
# ['model/model.pkl']

# %% [markdown]
# # testing

# %%
model = joblib.load('model/model.pkl')
test_data = pd.read_csv('testing_data/temperature_test_scaled.csv')

# %%
X_test = test_data.index.values.reshape(-1, 1)
predictions = model.predict(X_test)

# %%
test_data['Predicted Temperature'] = predictions

# %%
test_data
# Out:
#     temperature  day  Predicted Temperature
# 0     -0.225971  179               0.165938
# 1     -1.137441  115               0.163738
# 2      1.241435   96               0.161537
# 3     -1.259528   24               0.159337
# 4      1.342321    9               0.157137
# ..          ...  ...                    ...
# 75    -1.264514  111               0.000932
# 76    -1.022471  109              -0.001268
# 77    -0.534372  197              -0.003468
# 78    -1.332294  141              -0.005668
# 79     1.440044  216              -0.007868
#
# [80 rows x 3 columns]

# %%
# Расчет метрик
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Предполагаем, что в test_data есть столбец 'Actual Temperature' с истинными значениями
actual_values = test_data['temperature']

mae = mean_absolute_error(actual_values, predictions)
mse = mean_squared_error(actual_values, predictions)
r2 = r2_score(actual_values, predictions)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'R² Score: {r2}')
# Out:
# Mean Absolute Error (MAE): 0.9008815305474525
# Mean Squared Error (MSE): 1.0335615462011483
# R² Score: -0.03939454237200346

# %%
test_data
# Out:
#     temperature  day  Predicted Temperature
# 0     -0.225971  179               0.165938
# 1     -1.137441  115               0.163738
# 2      1.241435   96               0.161537
# 3     -1.259528   24               0.159337
# 4      1.342321    9               0.157137
# ..          ...  ...                    ...
# 75    -1.264514  111               0.000932
# 76    -1.022471  109              -0.001268
# 77    -0.534372  197              -0.003468
# 78    -1.332294  141              -0.005668
# 79     1.440044  216              -0.007868
#
# [80 rows x 3 columns]
